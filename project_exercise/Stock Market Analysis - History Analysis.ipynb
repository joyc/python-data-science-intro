# %%
# basic
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# get data
import pandas_datareader as pdr

# visual
import matplotlib.pyplot as plt
import seaborn as sns

# time
from datetime import datetime

# %%
start = datetime(2015,8,20)
alibaba = pdr.get_data_yahoo('BABA', start=start)
amazon = pdr.get_data_yahoo('AMZN', start=start)

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-08-19  73.559998  72.809998  73.150002  73.120003  18179400  73.120003
# 2015-08-20  72.779999  70.029999  71.980003  70.320000  20995600  70.320000
# 2015-08-21  70.660004  68.180000  69.320000  68.180000  29128600  68.180000
# 2015-08-24  65.800003  58.000000  58.160000  65.800003  31376400  65.800003
# 2015-08-25  70.330002  67.489998  68.839996  68.570000  29948400  68.570000

# %%
amazon.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2015-08-19  537.250000  529.000000  533.739990  532.919983   2324000
# 2015-08-20  533.250000  515.770020  530.390015  515.780029   4408000
# 2015-08-21  512.330017  494.470001  507.359985  494.470001   6706500
# 2015-08-24  476.579987  451.000000  463.579987  463.369995  10097600
# 2015-08-25  489.440002  466.250000  487.489990  466.369995   5679300
#
#              Adj Close
# Date
# 2015-08-19  532.919983
# 2015-08-20  515.780029
# 2015-08-21  494.470001
# 2015-08-24  463.369995
# 2015-08-25  466.369995

# %%
sns.set()
alibaba.plot()

# %%
# 只获取收盘价
alibaba['Adj Close'].plot(legend=True)
amazon['Adj Close'].plot(legend=True)

# %%
alibaba['Volume'].plot(label='Alibaba', legend=True)
amazon['Volume'].plot(label='Amazon', legend=True)

# %%
alibaba['High-Low'] = alibaba['High'] - alibaba['Low']
amazon['High-Low'] = amazon['High'] - amazon['Low']

# %%
alibaba['High-Low'].plot(label='Alibaba', legend=True)
amazon['High-Low'].plot(label='Amazon', legend=True)

# %%
# daily return
alibaba['daily-return'] = alibaba['Adj Close'].pct_change()
alibaba['daily-return'].plot(figsize=(10,4), linestyle='--', marker='o')

# %%
alibaba['daily-return'].plot(kind='hist')

# %%
alibaba['daily-return'].plot(kind='kde')

# %%
sns.distplot(alibaba['daily-return'].dropna(), bins=100, color='purple')

# %%
amazon['daily-return'] = alibaba['Adj Close'].pct_change()
amazon['daily-return'].plot(figsize=(10,5), linestyle='--', marker='o')

# %%
sns.distplot(amazon['daily-return'].dropna(), bins=100, color='orange')
