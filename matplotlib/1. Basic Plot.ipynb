# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [1, 2, 3]
b = [4, 5, 6]
plt.plot(a, b)

# %%
plt.show()

# %%
# %matplotlib inline

# %%
plt.plot(a, b)

# %%
plt.plot(a, b, '--')

# %%
plt.plot(a, b, '*')

# %%
c = [10, 8, 6]
d = [1, 8, 3]
plt.plot(a,b, '--', c,d, '*')
# Out:
# [<matplotlib.lines.Line2D at 0x11e079d30>,
#  <matplotlib.lines.Line2D at 0x11e079e80>]

# %%
t = np.arange(0.0, 2.0, 0.1)
s = np.sin(t*np.pi)
plt.plot(t,s, 'r--', label='aaa')
plt.plot(t*2,s, 'b--', label='bbb')
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
plt.legend()
