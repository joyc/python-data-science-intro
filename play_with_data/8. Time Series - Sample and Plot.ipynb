# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
t_range = pd.date_range('2018-01-01', '2018-12-31')

# %%
t_range
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
s = Series(np.random.rand(len(t_range)), index=t_range)

# %%
s['2018-01'].mean()
# Out:
# 0.4860813149672345

# %%
s_month = s.resample('M').mean()

# %%
s_month
# Out:
# 2018-01-31    0.486081
# 2018-02-28    0.534476
# 2018-03-31    0.438701
# 2018-04-30    0.489405
# 2018-05-31    0.503441
# 2018-06-30    0.626791
# 2018-07-31    0.524499
# 2018-08-31    0.428761
# 2018-09-30    0.587539
# 2018-10-31    0.444675
# 2018-11-30    0.621239
# 2018-12-31    0.476803
# Freq: M, dtype: float64

# %%
s_hour = s.resample('H').bfill()

# %%
s_hour
# Out:
# 2018-01-01 00:00:00    0.398090
# 2018-01-01 01:00:00    0.568679
# 2018-01-01 02:00:00    0.568679
# 2018-01-01 03:00:00    0.568679
# 2018-01-01 04:00:00    0.568679
# 2018-01-01 05:00:00    0.568679
# 2018-01-01 06:00:00    0.568679
# 2018-01-01 07:00:00    0.568679
# 2018-01-01 08:00:00    0.568679
# 2018-01-01 09:00:00    0.568679
# 2018-01-01 10:00:00    0.568679
# 2018-01-01 11:00:00    0.568679
# 2018-01-01 12:00:00    0.568679
# 2018-01-01 13:00:00    0.568679
# 2018-01-01 14:00:00    0.568679
# 2018-01-01 15:00:00    0.568679
# 2018-01-01 16:00:00    0.568679
# 2018-01-01 17:00:00    0.568679
# 2018-01-01 18:00:00    0.568679
# 2018-01-01 19:00:00    0.568679
# 2018-01-01 20:00:00    0.568679
# 2018-01-01 21:00:00    0.568679
# 2018-01-01 22:00:00    0.568679
# 2018-01-01 23:00:00    0.568679
# 2018-01-02 00:00:00    0.568679
# 2018-01-02 01:00:00    0.029249
# 2018-01-02 02:00:00    0.029249
# 2018-01-02 03:00:00    0.029249
# 2018-01-02 04:00:00    0.029249
# ...

# %%
s[0]
# Out:
# 0.3980895879945894

# %%
s[1]
# Out:
# 0.5686792523977978

# %%
s.plot()

# %%
# %matplotlib inline

# %%
s.plot()

# %%
s_month.plot()
