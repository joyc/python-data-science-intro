# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.0, 5.0)

# %%
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
len(x)
# Out:
# 50

# %%
y1 = np.sin(np.pi*x)
y2 = np.sin(np.pi*x*2)

# %%
plt.plot(x, y1, 'b--', label='sin(pi*x)')
plt.ylabel('y1 value')
plt.plot(x, y2, 'r--', label='sin(pi*x*2)')
plt.ylabel('y2 value')
plt.xlabel('x value')
plt.title('this is x-y value')
plt.legend()

# %%
plt.subplot(221)
plt.plot(x, y1, 'b--')
plt.subplot(222)
plt.plot(x, y2, 'r--')
plt.subplot(223)
plt.plot(x, y1, 'r*')
plt.subplot(224)
plt.plot(x, y2, 'g*')

# %%
plt.subplots(2,2)
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11cf33320>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x11d053a58>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x11d1202e8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x11d152898>]],
#        dtype=object))

# %%
figure, ax = plt.subplots(2,2)
ax[0][0].plot(x, y1)
ax[0][1].plot(x, y2)
ax[1][0].plot(x, y1, 'b--')
ax[1][1].plot(x, y2, 'r--')
