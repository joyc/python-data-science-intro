# %%
# basic
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# seaborn
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.9.0

# %%
s = Series(np.random.randn(1000))

# %%
plt.plot(s)

# %% [markdown]
# > 上图还是通过`Matplotlib`作图
# > 如果要通过`seaborn`作图，0.9后可以设置 `sns.set()`

# %%
sns.set() # 覆盖matplotlib的plt.plot()

# %%
plt.plot(s)
